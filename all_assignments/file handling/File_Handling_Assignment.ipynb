# %%
# 1. Write a Python program to read an entire text file

with open("sample.txt", "w") as file:
  file.write("Hello Sambodh!\n")
  file.write("This is your first text file.")

print("File created successfully")
# Out:
# File created successfully

# %%
with open("sample.txt", "r") as file:
  content = file.read()

print(content)
# Out:
# Hello Sambodh!
# This is your first text file.

# %%
#2. Write a Python program to read first n lines of a file.

n = int(input("Enter number of lines: "))

with open("sample.txt", "r") as file:
  for i in range(n):
    line = file.readline()

    if not line:
      break

    print(line, end="")
# Out:
# Enter number of lines: 5
# Apple
# Banana
# Mango
# Orange

# %%
#3. Write a Python program to append text to a file and display the text.

with open("sample.txt", "a") as file:
  file.write("\nThis line is appended to the file.")

print("!!!File updated successfully!!!")

with open("sample.txt", "r") as file:
  content = file.read()

print(content)
# Out:
# !!!File updated successfully!!!
# Hello Sambodh!
# This is your first text file.
# This line is appended to the file.

# %%
#4. Write a Python program to read last n lines of a file.

n = int(input("Enter number of lines:"))

with open("sample.txt", "r") as file:
  lines = file.readlines()

last_lines = lines[-n:]

for line in last_lines:
  print(line, end="")
# Out:
# Enter number of lines:1
# I am still learning python

# %%
#5. Write a Python program to read a file line by line and store it into a list.

lines_list = []

with open("sample.txt", "r") as file:
  for line in file:
    lines_list.append(line.strip())

print(lines_list)
# Out:
# ['Hello Sambodh!', 'This is your first text file.', 'This line is appended to the file.']

# %%
# 6. Write a Python program to read a file line by line store it into a variable.

content = ""

with open("sample.txt", "r") as file:
  for line in file:
    content += line

print(content)
# Out:
# Hello Sambodh!
# This is your first text file.
# This line is appended to the file.

# %%
with open ("sample.txt", "a") as file:
  file.write("\nI am still learning python")

with open("sample.txt", "r") as file:
  content = file.read()

print(content)
# Out:
# Hello Sambodh!
# This is your first text file.
# This line is appended to the file.I am still learning python
#  I am still learning python
# I am still learning python

# %%
# 7. Write a python program to find the longest words.

with open("sample.txt", "r") as file:
  words = file.read().split()

max_length = max(len(word) for word in words)

longest_words = [word for word in words if len(word) == max_length]

print("Longest word(s):", longest_words)
print("Length:", max_length)
# Out:
# Longest word(s): ['Sambodh!']
# Length: 8

# %%
# 8. Write a Python program to count the number of lines in a text files.

count = 0

with open("sample.txt", "r") as file:
  for line in file:
    count += 1

print("Number of lines :", count)
# Out:
# Number of lines : 2

# %%
# 9. Write a Python program to count the frequency of words in a file.

with open("sample.txt", "r") as file:
    words = file.read().split()

freq = {}

for word in words:
    freq[word] = freq.get(word, 0) + 1

print(freq)
# Out:
# {'Hello': 1, 'Sambodh!': 1, 'This': 2, 'is': 2, 'your': 1, 'first': 1, 'text': 1, 'file.': 2, 'line': 1, 'appended': 1, 'to': 1, 'the': 1}

# %%
#10. Write a Python program to get the file size of a plain file.

import os

file_size = os.path.getsize("sample.txt")

print("File Size:", file_size, "bytes")
# Out:
# File Size: 79 bytes

# %%
#11. Write a Python program to write a list to a file.
my_list = ["Apple", "Banana", "Mango", "Orange"]

with open("sample.txt", "w") as file:
  for item in my_list:
    file.write(item + "\n")

print("List written to file successfully!")
# Out:
# List written to file successfully!

# %%
#12. Write a Python program to copy the contents of a file to another file.

with open("sample.txt", "r") as source:
  content = source.read()

with open("copy.txt", "w") as destination:
  destination.write(content)

print("File copied successfully")
# Out:
# File copied successfully

# %%
#13. Write a Python program to read a random line from a file.
import random

with open("sample.txt", "r") as file:
  lines = file.readlines()

random_line = random.choice(lines)
print(random_line)
# Out:
# Banana

# %%
#14. Write a Python program to assess if a file is closed or not.

with open("sample.txt","r") as file:
  lines = file.readlines()

if lines:
  print(random.choice(lines))
else:
  print("File is Empty")
# Out:
# Banana

# %%
# 15.Write a Python program that takes a text file as input and returns the number of words of a given text file.

with open("sample.txt", "r") as file:
  text = file.read()

words = text.split()

count = len(words)

print("Number of words:", count)
# Out:
# Number of words: 4
